# %%
import requests as rq
import html5lib
from urllib.request import urlopen
from bs4 import BeautifulSoup 

YAHOOdata={}

print("YAHOO")

url = "https://tw.buy.yahoo.com/?sub=97&sort=-ptime&pg=1" 
html=urlopen(url)
bsobj=BeautifulSoup(html.read(),"html5lib")

response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器

for div in soup.findAll('div',{"class":"srp-pdtitle"}):
    for linkA in div.findAll('a'):
        
        childurl=linkA.get('href')
        #print(childurl)
        childresponse = rq.get(childurl) # 用 requests 的 get 方法把網頁抓下來
        childhtml_doc = childresponse.text # text 屬性就是 html 檔案
        childsoup = BeautifulSoup(childhtml_doc, "lxml") # 指定 lxml 作為解析器
        
        for childtitle in childsoup.find_all("div",{"class":"title"}):
            for childname in childtitle.findAll('h1'):
                YAHOOdata['商品']='商品:'+childname.text
                print(YAHOOdata['商品'], end='')
        
        for childdiv in childsoup.find_all("div",{"class":"priceinfo"}):
            for childprice in childdiv.find_all("span",{"class":"price"}):
                YAHOOdata['單價']=' ,單價:'+childprice.text
                print(YAHOOdata['單價'])


print("FINISH")
# Out:
# YAHOO
#  ,商品:Kracie 手作布丁聖代(25g) ,單價:109
#  ,商品:Bourbon北日本 超人氣餅乾禮盒 ,單價:199
#  ,商品:歐特 有機全果粒蔓越莓乾(200g) ,單價:300
#  ,商品:歐特 加州有機黑棗乾(200g) ,單價:200
#  ,商品:歐特 有機綜合堅果(120g) ,單價:200
#  ,商品:歐特 無調味有機核桃(150g) ,單價:380
#  ,商品:歐特 有機綜合純堅果(200g) ,單價:380
#  ,商品:歐特 無調味有機腰果(200g) ,單價:380
#  ,商品:歐特 無調味有機杏仁(200g) ,單價:380
#  ,商品:歐特 加州有機葡萄乾(230g) ,單價:200
#  ,商品:歐特 有機可可腰果(200g) ,單價:380
#  ,商品:歐特 有機全果粒蔓越莓乾(130g) ,單價:200
#  ,商品:天惠製果 二色最中餅(232g) ,單價:129
#  ,商品:栗山 月亮米果-馬鈴薯奶油(72g) ,單價:79
#  ,商品:十勝製果 十勝紅豆餡糖(80g) ,單價:89
#  ,商品:栗山米果 月亮米果-芝麻醬油(135g) ,單價:89
#  ,商品:殷茂 泰式碳烤蒜辣香魷片(24g) ,單價:39
#  ,商品:Bourbon北日本 愛麗絲雙色巧克力餅乾棒(172.8g) ,單價:139
#  ,商品:西村衛生 福吉鈣蛋酥(20gx6袋) ,單價:79
#  ,商品:入江製果 雙子星金平糖(65g) ,單價:59
#  ,商品:Ohkura 萌熊葡萄糖(90g) ,單價:55
#  ,商品:泰式碳烤香辣香魷片 (24g) ,單價:39
#  ,商品:明治 5連綜合果汁軟糖(90g) ,單價:79
#  ,商品:不二家 POP棒棒糖(121.8g) ,單價:79
#  ,商品:Befco栗山 三種類瀨戶原味米果(153g) ,單價:99
#  ,商品:Bourbon北日本 Kitty巧克力綜合餅乾禮盒(338.4g) ,單價:199
#  ,商品:Bourbon北日本 雞蛋餅乾(96g) ,單價:68
#  ,商品:統一生機 有機葡萄乾(300g) ,單價:150
#  ,商品:梓官漁會 戀戀蚵仔寮-芝麻梅魚(125g) ,單價:136
#  ,商品:花生達人吳啟魯 台灣名物黑金剛花生隨手包(160g) ,單價:79
#  ,商品:森之果物 嚴選有機甘栗(180g) ,單價:89
#  ,商品:快車肉乾 招牌特厚蜜汁豬肉乾(222g) ,單價:200
#  ,商品:快車肉乾 原味杏仁香脆肉紙(145g) ,單價:200
#  ,商品:Daeha 雪餅乾年糕風味(45g) ,單價:59
#  ,商品:Binggrae 螃蟹仔脆片芥末口味(70g) ,單價:59
#  ,商品:S&K 22穀養生糙米捲(180g) ,單價:109
#  ,商品:Binggrae 螃蟹仔脆片原味(70g) ,單價:59
#  ,商品:RUBIO 五星級洋芋片-魚子醬風味(110g) ,單價:95
#  ,商品:S&K 22穀養生糙米捲(600g) ,單價:299
#  ,商品:優格風味杏仁果(30g) ,單價:39
#  ,商品:RUBIO 五星級洋芋片-喜馬拉雅山粉紅鹽風味(110g) ,單價:95
#  ,商品:HAEMATT 京畿道韓式照燒海苔(4公克X12包) ,單價:129
#  ,商品:Heart 蠟筆小新手作居酒屋甜點組(17g) ,單價:119
#  ,商品:森永 小饅頭(42g) ,單價:89
#  ,商品:明治 ＭＯＧＹＵ草莓軟糖(35g) ,單價:59
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e5520d12b100> in <module>()
#      21         childurl=linkA.get('href')
#      22         #print(childurl)
# ---> 23         childresponse = rq.get(childurl) # 用 requests 的 get 方法把網頁抓下來
#      24         childhtml_doc = childresponse.text # text 屬性就是 html 檔案
#      25         childsoup = BeautifulSoup(childhtml_doc, "lxml") # 指定 lxml 作為解析器
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\j\appdata\local\programs\python\python36-32\lib\ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
